# %% [markdown]
# ## The objective of the project is to evaluate the factors that make films successful (In terms of revenue) and for that I'll be using a Linear Regression Model to find the effects of ten features on the target (Gross Domestic Revenue). I'll use a sample size of 1000 movies.

# %% [markdown]
# ## The ten factors are International Gross, Rating, Genre, Worldwide Gross, Domestic Gross, Opening Weekend Collection, Budget, Release Date, Runtime and Gross Revenue(Domestic Gross- Opening Weekend Collection)

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "Open_mil.PNG", width=1000, height=1000)

# %% [markdown]
# ## Above, I'm plotting Opening weekend collection and Gross Revenue to understand the relationship.

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "Budget GR.PNG", width=1000, height=1000)

# %% [markdown]
# ## Budget vs Domestic Revenue

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "ITL.PNG", width=1000, height=1000)

# %% [markdown]
# ## International Gross Collection vs Gross Revenue
