# %% [markdown]
# ## The objective of the project is to evaluate the factors that make films successful (In terms of revenue) and for that I'll be using a Linear Regression Model to find the effects of ten factors on Domestic Revenues Life of a Thousand Movies.

# %% [markdown]
# ## The ten factors are International collection, Rating, Genre, Worldwide collection, Domestic collection, First Weekend Collection, Gross Revenue, Budget, the date the movies were released, the Length(Runtime) and Profit of the movies.

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "mvp-project 2.PNG", width=1000, height=1000)

# %% [markdown]
# # Above, I'm plotting Opening weekend collection and profit to understand the degree of correlation.

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "Budget.PNG", width=1000, height=1000)

# %% [markdown]
# ## Budget vs Profit
